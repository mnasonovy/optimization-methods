# %%
import numpy as np
import matplotlib.pyplot as plt

# Функция
def f(x):
    return 1 - np.exp(-(x - 2)**2)

# Интервал и значения
x = np.linspace(-3, 5, 500)
y = f(x)

# График
plt.figure(figsize=(8, 5))
plt.plot(x, y, label=r"$f(x) = 1 - e^{-(x - 2)^2}$", color="navy")
plt.axvline(x=2, color="red", linestyle="--", label=r"Минимум при $x = 2$")
plt.scatter([2], [f(2)], color="red", zorder=5)

plt.title(r"График функции $f(x) = 1 - e^{-(x - 2)^2}$", fontsize=14)
plt.xlabel(r"$x$", fontsize=12)
plt.ylabel(r"$f(x)$", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Первая и вторая производные
def df(x):
    return 2 * (x - 2) * np.exp(-(x - 2)**2)

def d2f(x):
    return 2 * np.exp(-(x - 2)**2) * (1 - 2 * (x - 2)**2)

x = np.linspace(-3, 5, 500)

# f'(x)
plt.figure(figsize=(7, 4))
plt.plot(x, df(x), label=r"$f'(x)$", color="green")
plt.axhline(0, color="gray", linestyle=":")
plt.axvline(2, color="red", linestyle="--", label=r"$x = 2$")
plt.title("Первая производная $f'(x)$", fontsize=12)
plt.xlabel("$x$")
plt.ylabel("$f'(x)$")
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# f''(x)
plt.figure(figsize=(7, 4))
plt.plot(x, d2f(x), label=r"$f''(x)$", color="purple")
plt.axhline(0, color="gray", linestyle=":")
plt.axvline(2, color="red", linestyle="--", label=r"$x = 2$")
plt.title("Вторая производная $f''(x)$ — выпуклость и вогнутость", fontsize=12)
plt.xlabel("$x$")
plt.ylabel("$f''(x)$")
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Определение функции
def f(x):
    return 1 - np.exp(-(x - 2)**2)

x = np.linspace(1.5, 2.5, 400)
y = f(x)
approx = (x - 2)**2

# График
plt.figure(figsize=(7, 4))
plt.plot(x, y, label=r"$f(x) = 1 - e^{-(x - 2)^2}$", color="navy")
plt.plot(x, approx, '--', label=r"Аппроксимация: $(x - 2)^2$", color="orange")
plt.title("Сравнение $f(x)$ и $(x - 2)^2$ в окрестности $x = 2$", fontsize=13)
plt.xlabel("$x$", fontsize=12)
plt.ylabel("$f(x)$", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend(fontsize=11)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return 1 - np.exp(-(x - 2)**2)

# История сужения интервалов (N0–N12)
history = [
    (-3.000000, 5.000000),   # N0
    (0.999995, 5.000000),    # N2
    (0.999995, 3.000002),    # N4
    (1.999994, 3.000002),    # N6
    (1.999994, 2.500003),    # N8
    (1.999994, 2.250003),    # N10
    (1.999994, 2.125004)     # N12
]

# --- Автоматические границы по X ---
a_min = min(a for a, _ in history)
b_max = max(b for _, b in history)
pad = (b_max - a_min) * 0.05  # небольшой отступ от краёв
x_left, x_right = a_min - pad, b_max + pad

x = np.linspace(x_left, x_right, 600)
y = f(x)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(x, y, color='lightsteelblue', lw=2, label=r'$f(x) = 1 - e^{-(x - 2)^2}$')
ax.axvline(2, color='red', linestyle='--', lw=1.2, label='Минимум x = 2')

# Палитра для интервалов
colors = ['#7aa2f7', '#9d7cd8', '#bb9af7', '#e0af68', '#e06c75', '#98c379', '#56b6c2']

# --- Автоматический расчёт вертикальных отступов ---
step = abs(y.max()) * 0.08  # доля от высоты графика
for i, (a_i, b_i) in enumerate(history):
    color = colors[i % len(colors)]
    y_bottom = -step * (i + 1)
    ax.plot([a_i, a_i], [y_bottom, f(a_i)], color=color, lw=1.5)
    ax.plot([b_i, b_i], [y_bottom, f(b_i)], color=color, lw=1.5)
    ax.plot([a_i, b_i], [y_bottom, y_bottom], color=color, lw=1.5, label=f'Интервал N{i*2}')

# --- Оформление ---
ax.axhline(0, color='black', lw=1.3)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Автоматический диапазон по Y
y_top = y.max() + (y.max() * 0.05)
y_bottom = -step * (len(history) + 1)
ax.set_ylim(y_bottom, y_top)
ax.set_xlim(x_left, x_right)

ax.set_title('Сужение интервала (итерации N0–N12)', fontsize=13)
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=9)
ax.grid(True, alpha=0.25)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return 1 - np.exp(-(x - 2)**2)

# ✅ Корректная история (N14–N20)
history_14_20 = [
    (1.999994, 2.062504),   # N14
    (1.999994, 2.031254),   # N16
    (1.999994, 2.015629),   # N18
    (1.999994, 2.007816)    # N20
]

# --- Масштаб по X: ориентируемся по данным + небольшой отступ
a_min = min(a for a, _ in history_14_20)
b_max = max(b for _, b in history_14_20)
pad = 0.005
x_left, x_right = a_min - pad, b_max + pad

x = np.linspace(x_left, x_right, 800)
y = f(x)

fig, ax = plt.subplots(figsize=(9.5, 5))
ax.plot(x, y, lw=2, label=r'$f(x) = 1 - e^{-(x - 2)^2}$', color='lightsteelblue')
ax.axvline(2, color='red', linestyle='--', lw=1.2, label='Минимум x = 2')

# Цвета
colors = ['#7aa2f7', '#9d7cd8', '#bb9af7', '#e0af68']

# Скобы: до графика, компактно снизу
step = 0.0009  # единичный шаг между уровнями
for i, (a_i, b_i) in enumerate(history_14_20):
    color = colors[i % len(colors)]
    y_bottom = -step * (i + 1)
    ax.plot([a_i, a_i], [y_bottom, f(a_i)], color=color, lw=1.4)
    ax.plot([b_i, b_i], [y_bottom, f(b_i)], color=color, lw=1.4)
    ax.plot([a_i, b_i], [y_bottom, y_bottom], color=color, lw=1.4, label=f'Интервал N{14 + 2*i}')

# Оформление
ax.axhline(0, color='black', lw=1.3)                 # ось OX
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# По Y: небольшой запас сверху и снизу (под скобы)
y_top = y.max() + 0.002
y_low = -step * (len(history_14_20) + 2)
ax.set_ylim(y_low, y_top)

ax.set_xlim(x_left, x_right)
ax.set_title('Сужение интервала (итерации N14–N20)', fontsize=13)
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=9)
ax.grid(True, alpha=0.25)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return 1 - np.exp(-(x - 2)**2)

# ✅ Корректная история (N22–N30)
history_22_30 = [
    (1.999994, 2.003910),   # N22
    (1.999994, 2.001957),   # N24
    (1.999994, 2.000980),   # N26
    (1.999994, 2.000492),   # N28
    (1.999994, 2.000248)    # N30
]

# --- Масштаб по X: под реальные границы интервалов
a_min = min(a for a, _ in history_22_30)
b_max = max(b for _, b in history_22_30)
pad = 0.0005
x_left, x_right = a_min - pad, b_max + pad

x = np.linspace(x_left, x_right, 1000)
y = f(x)

fig, ax = plt.subplots(figsize=(9.5, 5))
ax.plot(x, y, lw=2, label=r'$f(x) = 1 - e^{-(x - 2)^2}$', color='lightsteelblue')
ax.axvline(2, color='red', linestyle='--', lw=1.2, label='Минимум x = 2')

# Цвета для 5 интервалов
colors = ['#7aa2f7', '#9d7cd8', '#bb9af7', '#e0af68', '#e06c75']

# Рисуем скобы до линии функции
step = 0.00008  # шаг по вертикали
for i, (a_i, b_i) in enumerate(history_22_30):
    color = colors[i % len(colors)]
    y_bottom = -step * (i + 1)
    ax.plot([a_i, a_i], [y_bottom, f(a_i)], color=color, lw=1.3)
    ax.plot([b_i, b_i], [y_bottom, f(b_i)], color=color, lw=1.3)
    ax.plot([a_i, b_i], [y_bottom, y_bottom], color=color, lw=1.3, label=f'Интервал N{22 + 2*i}')

# оформление
ax.axhline(0, color='black', lw=1.3)  # ось OX
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Диапазон по Y
y_top = y.max() + 0.0003
y_bottom = -step * (len(history_22_30) + 2)
ax.set_ylim(y_bottom, y_top)
ax.set_xlim(x_left, x_right)

ax.set_title('Сужение интервала (итерации N22–N30)', fontsize=13)
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=9)
ax.grid(True, alpha=0.25)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Целевая функция
def f(x):
    return 1 - np.exp(-(x - 2)**2)

# История сужения интервалов (N0–N4) — метод золотого сечения
history = [
    (-3.000000, 5.000000),    # N0
    (0.055728, 5.000000),     # N1
    (0.055728, 3.111456),     # N2
    (1.222912, 3.111456),     # N3
    (1.222912, 2.390097)      # N4
]

# --- Автоматические границы по X ---
a_min = min(a for a, _ in history)
b_max = max(b for _, b in history)
pad = (b_max - a_min) * 0.05
x_left, x_right = a_min - pad, b_max + pad

x = np.linspace(x_left, x_right, 600)
y = f(x)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(x, y, color='lightsteelblue', lw=2, label=r'$f(x) = 1 - e^{-(x - 2)^2}$')
ax.axvline(2, color='red', linestyle='--', lw=1.2, label='Минимум $x = 2$')

colors = ['#7aa2f7', '#9d7cd8', '#bb9af7', '#e0af68', '#e06c75']

# Построение интервалов и вертикальных отрезков
step = abs(y.max()) * 0.08
for i, (a_i, b_i) in enumerate(history):
    color = colors[i % len(colors)]
    y_bottom = -step * (i + 1)
    ax.plot([a_i, a_i], [y_bottom, f(a_i)], color=color, lw=1.5)
    ax.plot([b_i, b_i], [y_bottom, f(b_i)], color=color, lw=1.5)
    ax.plot([a_i, b_i], [y_bottom, y_bottom], color=color, lw=1.5, label=f'Интервал N{i}')

# Оформление
ax.axhline(0, color='black', lw=1.3)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

y_top = y.max() + (y.max() * 0.05)
y_bottom = -step * (len(history) + 1)
ax.set_ylim(y_bottom, y_top)
ax.set_xlim(x_left, x_right)

ax.set_title('Сужение интервала (итерации N0–N4)', fontsize=13)
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=9)
ax.grid(True, alpha=0.25)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Целевая функция
def f(x):
    return 1 - np.exp(-(x - 2)**2)

# История сужения интервалов (N5–N13) — метод золотого сечения
history = [
    (1.668737, 2.390097),   # N5
    (1.668737, 2.114562),   # N6
    (1.839027, 2.114562),   # N7
    (1.944272, 2.114562),   # N8
    (1.944272, 2.049517),   # N9
    (1.984472, 2.049517),   # N10
    (1.984472, 2.024672),   # N11
    (1.984472, 2.009317),   # N12
    (1.993962, 2.009317),   # N13
]

# --- Автоматические границы по X ---
a_min = min(a for a, _ in history)
b_max = max(b for _, b in history)
pad = (b_max - a_min) * 0.05
x_left, x_right = a_min - pad, b_max + pad

x = np.linspace(x_left, x_right, 600)
y = f(x)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(x, y, color='lightsteelblue', lw=2, label=r'$f(x) = 1 - e^{-(x - 2)^2}$')
ax.axvline(2, color='red', linestyle='--', lw=1.2, label='Минимум $x = 2$')

# Палитра цветов
colors = ['#7aa2f7', '#9d7cd8', '#bb9af7', '#e0af68', '#e06c75', '#98c379', '#56b6c2', '#d19a66', '#61afef']

# Построение интервалов
step = abs(y.max()) * 0.08
for i, (a_i, b_i) in enumerate(history):
    color = colors[i % len(colors)]
    y_bottom = -step * (i + 1)
    ax.plot([a_i, a_i], [y_bottom, f(a_i)], color=color, lw=1.5)
    ax.plot([b_i, b_i], [y_bottom, f(b_i)], color=color, lw=1.5)
    ax.plot([a_i, b_i], [y_bottom, y_bottom], color=color, lw=1.5, label=f'Интервал N{5 + i}')

# Оформление
ax.axhline(0, color='black', lw=1.3)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
y_top = y.max() + (y.max() * 0.05)
y_bottom = -step * (len(history) + 1)
ax.set_ylim(y_bottom, y_top)
ax.set_xlim(x_left, x_right)

ax.set_title('Сужение интервала (итерации N5–N13)', fontsize=13)
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=9)
ax.grid(True, alpha=0.25)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Целевая функция
def f(x):
    return 1 - np.exp(-(x - 2)**2)

# История сужения интервалов (N14–N24) — метод золотого сечения
history = [
    (1.993962, 2.003452),   # N14
    (1.997587, 2.003452),   # N15
    (1.997587, 2.001211),   # N16
    (1.998971, 2.001211),   # N17
    (1.998971, 2.000356),   # N18
    (1.999500, 2.000356),   # N19
    (1.999827, 2.000356),   # N20
    (1.999827, 2.000154),   # N21
    (1.999952, 2.000154),   # N22
    (1.999952, 2.000077),   # N23
    (1.999952, 2.000029),   # N24
]

# --- Автоматические границы по X ---
a_min = min(a for a, _ in history)
b_max = max(b for _, b in history)
pad = (b_max - a_min) * 0.05
x_left, x_right = a_min - pad, b_max + pad

x = np.linspace(x_left, x_right, 600)
y = f(x)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(x, y, color='lightsteelblue', lw=2, label=r'$f(x) = 1 - e^{-(x - 2)^2}$')
ax.axvline(2, color='red', linestyle='--', lw=1.2, label='Минимум $x = 2$')

# Палитра цветов
colors = [
    '#7aa2f7', '#9d7cd8', '#bb9af7', '#e0af68', '#e06c75',
    '#98c379', '#56b6c2', '#d19a66', '#61afef', '#c678dd', '#be5046'
]

# Построение интервалов
step = abs(y.max()) * 0.08
for i, (a_i, b_i) in enumerate(history):
    color = colors[i % len(colors)]
    y_bottom = -step * (i + 1)
    ax.plot([a_i, a_i], [y_bottom, f(a_i)], color=color, lw=1.5)
    ax.plot([b_i, b_i], [y_bottom, f(b_i)], color=color, lw=1.5)
    ax.plot([a_i, b_i], [y_bottom, y_bottom], color=color, lw=1.5, label=f'Интервал N{14 + i}')

# Оформление
ax.axhline(0, color='black', lw=1.3)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
y_top = y.max() + (y.max() * 0.05)
y_bottom = -step * (len(history) + 1)
ax.set_ylim(y_bottom, y_top)
ax.set_xlim(x_left, x_right)

ax.set_title('Сужение интервала (итерации N14–N24)', fontsize=13)
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=9)
ax.grid(True, alpha=0.25)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Целевая функция
def f(x):
    return 1 - np.exp(-(x - 2)**2)

# История сужения интервалов (N0–N8) — метод Фибоначчи
history = [
    (-3.000000, 5.000000),    # N0
    (0.055728, 5.000000),     # N1
    (0.055728, 3.111456),     # N2
    (1.222912, 3.111456),     # N3
    (1.222912, 2.390097),     # N4
    (1.668737, 2.390097),     # N5
    (1.668737, 2.114562),     # N6
    (1.839027, 2.114562),     # N7
    (1.944272, 2.114562)      # N8
]

# --- Автоматические границы по X ---
a_min = min(a for a, _ in history)
b_max = max(b for _, b in history)
pad = (b_max - a_min) * 0.05
x_left, x_right = a_min - pad, b_max + pad

x = np.linspace(x_left, x_right, 600)
y = f(x)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(x, y, color='lightsteelblue', lw=2, label=r'$f(x) = 1 - e^{-(x - 2)^2}$')
ax.axvline(2, color='red', linestyle='--', lw=1.2, label='Минимум $x = 2$')

colors = ['#7aa2f7', '#9d7cd8', '#bb9af7', '#e0af68', '#e06c75', '#98c379', '#56b6c2', '#d19a66', '#61afef']

# Построение интервалов и вертикальных отрезков
step = abs(y.max()) * 0.08
for i, (a_i, b_i) in enumerate(history):
    color = colors[i % len(colors)]
    y_bottom = -step * (i + 1)
    ax.plot([a_i, a_i], [y_bottom, f(a_i)], color=color, lw=1.5)
    ax.plot([b_i, b_i], [y_bottom, f(b_i)], color=color, lw=1.5)
    ax.plot([a_i, b_i], [y_bottom, y_bottom], color=color, lw=1.5, label=f'Интервал N{i}')

# Оформление
ax.axhline(0, color='black', lw=1.3)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

y_top = y.max() + (y.max() * 0.05)
y_bottom = -step * (len(history) + 1)
ax.set_ylim(y_bottom, y_top)
ax.set_xlim(x_left, x_right)

ax.set_title('Сужение интервала (итерации N0–N8)', fontsize=13)
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=9)
ax.grid(True, alpha=0.25)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Целевая функция
def f(x):
    return 1 - np.exp(-(x - 2)**2)

# История сужения интервалов (N9–N16) — метод Фибоначчи
history = [
    (1.944272, 2.049517),   # N9
    (1.984472, 2.049517),   # N10
    (1.984472, 2.024672),   # N11
    (1.984472, 2.009317),   # N12
    (1.993962, 2.009317),   # N13
    (1.993962, 2.003452),   # N14
    (1.997586, 2.003452),   # N15
    (1.997586, 2.001211)    # N16
]

# --- Автоматические границы по X ---
a_min = min(a for a, _ in history)
b_max = max(b for _, b in history)
pad = (b_max - a_min) * 0.05
x_left, x_right = a_min - pad, b_max + pad

x = np.linspace(x_left, x_right, 600)
y = f(x)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(x, y, color='lightsteelblue', lw=2, label=r'$f(x) = 1 - e^{-(x - 2)^2}$')
ax.axvline(2, color='red', linestyle='--', lw=1.2, label='Минимум $x = 2$')

# Палитра цветов
colors = ['#7aa2f7', '#9d7cd8', '#bb9af7', '#e0af68', '#e06c75', '#98c379', '#56b6c2', '#d19a66']

# Построение интервалов
step = abs(y.max()) * 0.08
for i, (a_i, b_i) in enumerate(history):
    color = colors[i % len(colors)]
    y_bottom = -step * (i + 1)
    ax.plot([a_i, a_i], [y_bottom, f(a_i)], color=color, lw=1.5)
    ax.plot([b_i, b_i], [y_bottom, f(b_i)], color=color, lw=1.5)
    ax.plot([a_i, b_i], [y_bottom, y_bottom], color=color, lw=1.5, label=f'Интервал N{9 + i}')

# Оформление
ax.axhline(0, color='black', lw=1.3)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
y_top = y.max() + (y.max() * 0.05)
y_bottom = -step * (len(history) + 1)
ax.set_ylim(y_bottom, y_top)
ax.set_xlim(x_left, x_right)

ax.set_title('Сужение интервала (итерации N9–N16)', fontsize=13)
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=9)
ax.grid(True, alpha=0.25)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Целевая функция
def f(x):
    return 1 - np.exp(-(x - 2)**2)

# История сужения интервалов (N17–N24) — метод Фибоначчи
history = [
    (1.998970, 2.001211),   # N17
    (1.998970, 2.000354),   # N18
    (1.999497, 2.000354),   # N19
    (1.999827, 2.000354),   # N20
    (1.999827, 2.000157),   # N21
    (1.999959, 2.000157),   # N22
    (1.999959, 2.000091),   # N23
    (1.999959, 2.000025)    # N24
]

# --- Автоматические границы по X ---
a_min = min(a for a, _ in history)
b_max = max(b for _, b in history)
pad = (b_max - a_min) * 0.1  # увеличенный отступ для узкого интервала
x_left, x_right = a_min - pad, b_max + pad

x = np.linspace(x_left, x_right, 600)
y = f(x)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(x, y, color='lightsteelblue', lw=2, label=r'$f(x) = 1 - e^{-(x - 2)^2}$')
ax.axvline(2, color='red', linestyle='--', lw=1.2, label='Минимум $x = 2$')

colors = ['#7aa2f7', '#9d7cd8', '#bb9af7', '#e0af68', '#e06c75', '#98c379', '#56b6c2', '#d19a66']

# Построение интервалов и вертикальных отрезков
step = abs(y.max()) * 0.08
for i, (a_i, b_i) in enumerate(history):
    color = colors[i % len(colors)]
    y_bottom = -step * (i + 1)
    ax.plot([a_i, a_i], [y_bottom, f(a_i)], color=color, lw=1.5)
    ax.plot([b_i, b_i], [y_bottom, f(b_i)], color=color, lw=1.5)
    ax.plot([a_i, b_i], [y_bottom, y_bottom], color=color, lw=1.5, label=f'Интервал N{17 + i}')

# Оформление
ax.axhline(0, color='black', lw=1.3)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
y_top = y.max() + (y.max() * 0.05)
y_bottom = -step * (len(history) + 1)
ax.set_ylim(y_bottom, y_top)
ax.set_xlim(x_left, x_right)

ax.set_title('Сужение интервала (итерации N17–N24)', fontsize=13)
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=9)
ax.grid(True, alpha=0.25)
plt.tight_layout()
plt.show()
